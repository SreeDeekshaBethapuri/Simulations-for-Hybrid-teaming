# %% [markdown]
# In both cases, the agent must act in an enviroment where something cruicial is uncertain. The model updates its believes based on observations and uses that to plan safely or helpfully.
#
#
# Differences :
#
# CIRL - THe reward function that the human wants robot to optimize is hidden, where as in DRL, the true environment dynamics is hidde,
#
# Belief is over:
# Distribution over reqard parameters theta in CIRL, where as the distribution over MDP models.

# %% [markdown]
# All four things fall into uncertain category.
#
#
# in these, the first two, L2D and L2C, are one step decisions, where as the CIRL and DRL are sequential decision making steps.

# %% [markdown]
# Potentially in the paper:
#
# 4 for now.
# We compare four state of the art framework approaches to handling uncertainity with human collaboration. These algorithms approach uncertainity and trust from fundamentally different angles in Human-AI collaboration.
#
# We identify hoe each method addresses different sources of uncertainity: model-based, or balue based, and use this to evaluate their effectiveness in risk-sensitive environment by testing them on a medical diagnosis task as a test bed.
#
#
# Key contributions would be:
#
# Unified comparision of the algorithms
# Evaluation under a medical setting
#
#
#
# Since they share partially observablle MDPs as a mathetmatical source(DRL, and CIRL), we can show how these sequential decision making is different or an upgrade of defer learning(single step), and how all these differ from the Complement learning.
#
#
# Learning method for each algorithm so far:
#
# CIRL - Partially observable MDP
# DRL - posterier stampling (Bayesian RL)
# L2D - Classification
# L2C - Joint Prediction Loss.

# %% [markdown]
# L2D - The code is up and running for their daatset
#
# L2C - No open souce code (Microsft dudes) - idk we should check other versions of this, but this paper was a benchmark, sort of
#
# CIRL - https://github.com/DentanJeremie/MAP578-Cooperative-Inverse-Reinforcement-Learning
#
# can check this out
#
# DRL - Math heavy (again) ddidnt find a opensource implementation.
